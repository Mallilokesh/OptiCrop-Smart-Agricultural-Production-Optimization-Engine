# %% [markdown]
# # OptiCrop Model Training
#
# This notebook mirrors the training pipeline used by the Flask app. Run the project script `python scripts/train_model.py` for the canonical training workflow.

# %%
from pathlib import Path
import sys

BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(BASE_DIR))

from src.model import train_and_select_model, save_model

payload = train_and_select_model(BASE_DIR)
payload['results']

# %%
save_model(payload, BASE_DIR / 'artifacts' / 'best_model.pkl')
payload['best_model_name'], payload['best_accuracy']
